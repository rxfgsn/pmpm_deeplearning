# %% [markdown]
# # Menggunakan Library Tensorflow

# %%
import tensorflow as tf ##jika error,  install tensorflow terlebih dahulu
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import logging
logging.getLogger('matplotlib.font_manager').disabled = True
import random

seed_value = 42
tf.random.set_seed(seed_value) 
np.random.seed(seed_value)      
random.seed(seed_value)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist  
                                                 
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure() 
plt.imshow(train_images[0]) 
plt.colorbar() 
plt.grid(False)
plt.show()

# %%
train_images = train_images.reshape(-1, 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(-1, 28, 28, 1).astype('float32') / 255

# %%
plt.figure(figsize=(10,10)) 
for i in range(25): 
    plt.subplot(5,5,i+1) 
    plt.xticks([]) 
    plt.yticks([]) 
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary) 
    plt.xlabel(class_names[train_labels[i]]) 
plt.show()

# %%
model_tf = tf.keras.Sequential([ 
    tf.keras.layers.Input(shape=(28, 28)), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(300, activation='relu'),  
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10)
])

# %%
model_tf.compile(optimizer='adam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    min_delta=0.0001,
    restore_best_weights=True  
)


history = model_tf.fit(
    train_images, train_labels,
    epochs=40,
    validation_data=(test_images, test_labels),
    callbacks=[early_stopping]  
)
# Out:
# Epoch 1/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5267 - loss: 1.2510 - val_accuracy: 0.7667 - val_loss: 0.6130
# Epoch 2/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7643 - loss: 0.6333 - val_accuracy: 0.8077 - val_loss: 0.5219
# Epoch 3/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8022 - loss: 0.5452 - val_accuracy: 0.8267 - val_loss: 0.4800
# Epoch 4/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8240 - loss: 0.4947 - val_accuracy: 0.8380 - val_loss: 0.4484
# Epoch 5/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8327 - loss: 0.4626 - val_accuracy: 0.8467 - val_loss: 0.4285
# Epoch 6/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8418 - loss: 0.4395 - val_accuracy: 0.8502 - val_loss: 0.4203
# Epoch 7/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8469 - loss: 0.4251 - val_accuracy: 0.8555 - val_loss: 0.4070
# Epoch 8/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8521 - loss: 0.4094 - val_accuracy: 0.8550 - val_loss: 0.4000
# Epoch 9/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8556 - loss: 0.4023 - val_accuracy: 0.8582 - val_loss: 0.3954
# Epoch 10/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8595 - loss: 0.3900 - val_accuracy: 0.8587 - val_loss: 0.3878
# Epoch 11/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8614 - loss: 0.3832 - val_accuracy: 0.8628 - val_loss: 0.3833
# Epoch 12/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8625 - loss: 0.3785 - val_accuracy: 0.8653 - val_loss: 0.3776
# Epoch 13/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8661 - loss: 0.3709 - val_accuracy: 0.8641 - val_loss: 0.3800
# Epoch 14/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8693 - loss: 0.3650 - val_accuracy: 0.8656 - val_loss: 0.3739
# Epoch 15/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8717 - loss: 0.3574 - val_accuracy: 0.8690 - val_loss: 0.3649
# Epoch 16/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8716 - loss: 0.3556 - val_accuracy: 0.8702 - val_loss: 0.3676
# Epoch 17/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8732 - loss: 0.3508 - val_accuracy: 0.8691 - val_loss: 0.3666
# Epoch 18/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8744 - loss: 0.3487 - val_accuracy: 0.8734 - val_loss: 0.3590
# Epoch 19/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8756 - loss: 0.3425 - val_accuracy: 0.8725 - val_loss: 0.3559
# Epoch 20/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8750 - loss: 0.3382 - val_accuracy: 0.8676 - val_loss: 0.3673
# Epoch 21/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8781 - loss: 0.3355 - val_accuracy: 0.8723 - val_loss: 0.3547
# Epoch 22/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8777 - loss: 0.3346 - val_accuracy: 0.8754 - val_loss: 0.3516
# Epoch 23/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8803 - loss: 0.3303 - val_accuracy: 0.8710 - val_loss: 0.3612
# Epoch 24/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8820 - loss: 0.3266 - val_accuracy: 0.8746 - val_loss: 0.3559
# Epoch 25/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8822 - loss: 0.3239 - val_accuracy: 0.8755 - val_loss: 0.3509
# Epoch 26/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8820 - loss: 0.3218 - val_accuracy: 0.8748 - val_loss: 0.3479
# Epoch 27/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8840 - loss: 0.3176 - val_accuracy: 0.8755 - val_loss: 0.3505

# %%
fig = plt.figure()
plt.plot(history.history['val_accuracy'], color='teal', label='Validation Accuracy')  
plt.plot(history.history['accuracy'], color='orange', label='Train Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['val_loss'], color='blue', label='Validation Loss')  
plt.plot(history.history['loss'], color='orange', label='Train Loss')
plt.legend(loc='upper left')
plt.show()

# %%
test_loss, test_acc_tf = model_tf.evaluate(test_images, test_labels, verbose=2) 
                                                                                
print('\nTest accuracy:', test_acc_tf)
# Out:
# 313/313 - 0s - 624us/step - accuracy: 0.8754 - loss: 0.3516
#
# Test accuracy: 0.8754000067710876

# %%
probability_model = tf.keras.Sequential([model_tf, 
                                         tf.keras.layers.Softmax()])

# %%
predictions_tf = probability_model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step

# %%
predictions_tf[0]
# Out:
# array([4.4902495e-07, 2.0240104e-07, 3.1571614e-09, 2.0557241e-06,
#        4.5176916e-09, 4.9694744e-03, 2.3381897e-08, 1.3975626e-02,
#        1.5323531e-05, 9.8103678e-01], dtype=float32)

# %%
np.argmax(predictions_tf[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  
  true_label, img = true_label[i], img[i]                                                      
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)
  
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label): 

                                                       
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 5 
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions_tf[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions_tf[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_tf[i]) == test_labels[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) * 100  

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_tf[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[i] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_tf[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
img = test_images[1] 

print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
predictions_single = probability_model.predict(img) 
print(predictions_single)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[5.6237310e-05 4.1778865e-09 9.9237740e-01 2.3865723e-06 1.9178358e-03
#   1.2107663e-09 5.6461086e-03 2.7883433e-24 4.7027232e-08 7.7941228e-19]]

# %%
plot_value_array(1, predictions_single[0], test_labels) 
_ = plt.xticks(range(10), rotation=45) 
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# 2

# %%
df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_tf, axis=1),  
    'Proba_0': predictions_tf[:, 0],  
    'Proba_1': predictions_tf[:, 1]  
})

pixels = test_images.reshape(len(test_images), -1)

df_pixels = pd.DataFrame(pixels, columns=[f'pixel{i+1}' for i in range(28*28)])

df_test = pd.concat([df_test, df_pixels], axis=1)

# %%
df_plot = df_test.sample(16, random_state=42).copy()

fig, ax = plt.subplots(4, 4, figsize=(10, 10))

rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]
    
    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100

    true_class = df_plot['Target'].values[i]

    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')

    axi.set(xticks=[], yticks=[],
            xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")

    edge_color = 'green' if predicted_class == true_class else 'red'
    axi.spines[:].set_edgecolor(edge_color)
    axi.spines[:].set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Menggunakan Library Scikit-Learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import tensorflow as tf

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

# %%
from sklearn.datasets import fetch_openml
fashion_mnist = fetch_openml('Fashion-MNIST', version=1)

train_images = fashion_mnist.data[:60000]
train_labels = fashion_mnist.target[:60000].astype(int)   
test_images = fashion_mnist.data[60000:]
test_labels = fashion_mnist.target[60000:].astype(int)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, log_loss
from sklearn.model_selection import train_test_split
import numpy as np

train_images_split, val_images, train_labels_split, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
    
)

model_sklearn = MLPClassifier(hidden_layer_sizes=(128, 300),
                        activation='relu',
                        alpha=0.0001,
                        learning_rate_init=0.0001,
                        early_stopping=True,
                        validation_fraction=0.2,
                        n_iter_no_change=10,
                        random_state=42,
                        
                        verbose=True)

model_sklearn.fit(train_images_split, train_labels_split)
training_loss = model_sklearn.loss_curve_
# Out:
# Iteration 1, loss = 1.19225647
# Validation score: 0.775208
# Iteration 2, loss = 0.60546272
# Validation score: 0.813646
# Iteration 3, loss = 0.51301664
# Validation score: 0.826042
# Iteration 4, loss = 0.47370844
# Validation score: 0.837083
# Iteration 5, loss = 0.44747234
# Validation score: 0.843542
# Iteration 6, loss = 0.42759971
# Validation score: 0.850833
# Iteration 7, loss = 0.41331934
# Validation score: 0.846562
# Iteration 8, loss = 0.40119708
# Validation score: 0.857708
# Iteration 9, loss = 0.39100949
# Validation score: 0.856875
# Iteration 10, loss = 0.38237206
# Validation score: 0.861875
# Iteration 11, loss = 0.37407931
# Validation score: 0.862500
# Iteration 12, loss = 0.36680117
# Validation score: 0.867396
# Iteration 13, loss = 0.36049183
# Validation score: 0.867396
# Iteration 14, loss = 0.35347734
# Validation score: 0.868854
# Iteration 15, loss = 0.34978190
# Validation score: 0.868333
# Iteration 16, loss = 0.34265706
# Validation score: 0.872083
# Iteration 17, loss = 0.33673509
# Validation score: 0.869687
# Iteration 18, loss = 0.33315066
# Validation score: 0.876146
# Iteration 19, loss = 0.32831950
# Validation score: 0.873958
# Iteration 20, loss = 0.32346369
# Validation score: 0.879167
# Iteration 21, loss = 0.31797826
# Validation score: 0.873229
# Iteration 22, loss = 0.31524517
# Validation score: 0.875104
# Iteration 23, loss = 0.31116924
# Validation score: 0.879375
# Iteration 24, loss = 0.30732932
# Validation score: 0.881458
# Iteration 25, loss = 0.30509810
# Validation score: 0.879583
# Iteration 26, loss = 0.30197584
# Validation score: 0.882188
# Iteration 27, loss = 0.29616304
# Validation score: 0.883854
# Iteration 28, loss = 0.29450287
# Validation score: 0.883750
# Iteration 29, loss = 0.29275523
# Validation score: 0.882292
# Iteration 30, loss = 0.28802764
# Validation score: 0.883437
# Iteration 31, loss = 0.28555880
# Validation score: 0.881771
# Iteration 32, loss = 0.28186840
# Validation score: 0.883542
# Iteration 33, loss = 0.27855064
# Validation score: 0.882812
# Iteration 34, loss = 0.27793345
# Validation score: 0.885833
# Iteration 35, loss = 0.27493368
# Validation score: 0.886771
# Iteration 36, loss = 0.27205889
# Validation score: 0.884792
# Iteration 37, loss = 0.27036044
# Validation score: 0.887708
# Iteration 38, loss = 0.26689387
# Validation score: 0.885208
# Iteration 39, loss = 0.26399014
# Validation score: 0.886458
# Iteration 40, loss = 0.26214339
# Validation score: 0.881458
# Iteration 41, loss = 0.26068410
# Validation score: 0.887292
# Iteration 42, loss = 0.25677783
# Validation score: 0.891563
# Iteration 43, loss = 0.25556644
# Validation score: 0.888333
# Iteration 44, loss = 0.25337829
# Validation score: 0.889792
# Iteration 45, loss = 0.25114543
# Validation score: 0.887813
# Iteration 46, loss = 0.24864136
# Validation score: 0.888854
# Iteration 47, loss = 0.24636230
# Validation score: 0.889062
# Iteration 48, loss = 0.24646760
# Validation score: 0.889687
# Iteration 49, loss = 0.24139076
# Validation score: 0.890312
# Iteration 50, loss = 0.24081977
# Validation score: 0.886771
# Iteration 51, loss = 0.24047436
# Validation score: 0.883542
# Iteration 52, loss = 0.23869161
# Validation score: 0.889479
# Iteration 53, loss = 0.23477711
# Validation score: 0.887604
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(
    model_sklearn, train_images, train_labels, train_sizes=np.linspace(0.1, 1.0, 10), cv=5,
    scoring='neg_log_loss', random_state=42, n_jobs=-1)

train_loss_mean = -train_scores.mean(axis=1)
val_loss_mean = -val_scores.mean(axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_loss_mean, label='Training Loss')
plt.plot(train_sizes, val_loss_mean, label='Validation Loss')
plt.xlabel('Trainig Set Size')
plt.ylabel('Loss')
plt.title('Learning Curve (Training vs Validation Loss)')
plt.legend()
plt.show()

# %%
test_predictions = model_sklearn.predict(test_images)
test_acc_sklearn = accuracy_score(test_labels, test_predictions)
print('\nTest accuracy:', test_acc_sklearn)
# Out:
# Test accuracy: 0.8735

# %%
print("\nClassification Report:\n", classification_report(test_labels, test_predictions))

predictions_proba = model_sklearn.predict_proba(test_images)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1000
#            1       0.98      0.97      0.98      1000
#            2       0.74      0.83      0.78      1000
#            3       0.82      0.91      0.87      1000
#            4       0.81      0.77      0.79      1000
#            5       0.96      0.96      0.96      1000
#            6       0.72      0.62      0.67      1000
#            7       0.93      0.96      0.94      1000
#            8       0.97      0.95      0.96      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %%
predictions_sklearn = model_sklearn.predict_proba(test_images)
print(predictions_sklearn[0])
print("Predicted label for first image:", np.argmax(predictions_sklearn[0]))

print ("Actual label for first image:", test_labels.iloc[0])
# Out:
# [1.79822903e-05 1.62301741e-06 6.17684057e-05 1.61076305e-04
#  4.91255606e-05 9.88613447e-03 3.74335964e-04 3.92850572e-02
#  2.71464639e-03 9.47448250e-01]
# Predicted label for first image: 9
# Actual label for first image: 9

# %%
def plot_image(i, predictions_array, true_label, img):
    
    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28) 
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)

def plot_value_array(i, predictions_array, true_label):
    
    true_label = true_label.iloc[i]
    plt.grid(False) 
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 1
plt.figure(figsize=(6, 3))
plt.subplot(1,2,1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i, predictions_sklearn[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_sklearn[i]) == test_labels.iloc[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) * 100

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_sklearn[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[j] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_sklearn[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n_samples = 10000

df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_sklearn, axis=1),
    'Proba_0' : predictions_sklearn[:, 0],
    'Proba_1' : predictions_sklearn[:, 1]
})

df_test['Proba_0'] = df_test['Proba_0'] / (df_test['Proba_0'] + df_test['Proba_1'])
df_test['Proba_1'] = 1 - df_test['Proba_0']

for i in range(1, 28*28 + 1):
    df_test[f'pixel{i}'] = np.random.randint(0, 256, n_samples)

df_plot = df_test.sample(16, random_state=42).copy()

fig, ax = plt.subplots(4, 4, figsize=(10, 10))
rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]
    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100
    true_class = df_plot['Target'].values[i]
    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')
    axi.set(xticks=[], yticks=[],
            xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")
    edge_color = 'green' if predicted_class == true_class else 'red'
    for spine in axi.spines.values():
        spine.set_edgecolor(edge_color)
        spine.set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')
fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_image(i, predictions_array, true_label, img):
    
    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28)
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap='gray') 
    
    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)
    
def plot_value_array(i, predictions_array, true_label):
    true_label = true_label.iloc[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#77777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

i = 19
plt.figure(figsize=(6, 3))

plt.subplot(1,2,1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)

plt.subplot(1,2,2)
plot_value_array(i, predictions_sklearn[i], test_labels)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def save_image_only(i, true_label, img):
    img = img.iloc[i].values.reshape(28, 28)
    
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.savefig(f"image_only_{i}.jpeg", bbox_inches='tight', pad_inches=0)
    plt.close()

i = 19
save_image_only(i, test_labels, test_images)

# %%
import pandas as pd

data = {
    'Model' : ['TensorFlow', 'Scikit-Learn'],
    'Accuracy' : [test_acc_tf, test_acc_sklearn],
    'Architecture' : ['Neural Network (2 hidden layers)', 'MLP (2 hidden layer)'],
    'Early Stopping' : ['Yes', 'Yes']
}

comparison_df = pd.DataFrame(data)

best_model = comparison_df.loc[comparison_df['Accuracy'].idxmax()]

print("Comparison of Model Performance:")
print(comparison_df)

print("\nBest Model Based on Accuracy:")
print(best_model)
# Out:
# Comparison of Model Performance:
#           Model  Accuracy                      Architecture Early Stopping
# 0    TensorFlow    0.8754  Neural Network (2 hidden layers)            Yes
# 1  Scikit-Learn    0.8735              MLP (2 hidden layer)            Yes
#
# Best Model Based on Accuracy:
# Model                                   TensorFlow
# Accuracy                                    0.8754
# Architecture      Neural Network (2 hidden layers)
# Early Stopping                                 Yes
# Name: 0, dtype: object

# %%
#Cara dump h5 jika model tensorflow yang terbaik
import pickle
import tensorflow as tf

# Menyimpan model TensorFlow
model_tf.save('best_model_tf.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
